# %%
file_path="OZONE_DATA.csv"
print(file_path)
# Out:
# OZONE_DATA.csv

# %%
#read data frame
import pandas as pd

df = pd.read_csv(file_path)

df
# Out:
#       Time   Press GeopAlt    Temp  RH  O3_mPa O3_ppmv   O3_DU Wind_Dir  \
# 0      sec     hPa      km       C   %     mPa    ppmv      DU      deg
# 1        0   826.3     1.8    22.3  62  3.8806   0.047       0       42
# 2        2  824.01   1.824    22.1  53  3.8806  0.0471    0.09       89
# 3        4   822.7   1.838   21.98  53  3.8806  0.0472    0.13       91
# 4        6  821.55    1.85   21.96  54  3.8398  0.0467    0.18       88
# ...    ...     ...     ...     ...  ..     ...     ...     ...      ...
# 3681  7360    6.42  34.039  -37.51   1  6.6706    10.4  221.23       91
# 3682  7362    6.41   34.05  -37.62   1  6.6303    10.3  221.31       91
# 3683  7364     6.4  34.061   -37.6   1  6.6312    10.4  221.39       91
# 3684  7366     6.4  34.061  -37.36   1  6.6312    10.4  221.39       91
# 3685  7368    6.39  34.071  -37.12   1  6.6318    10.4  221.48       91
#
#      Wind_Spd  TPump O3CellI  GPS_Lat  GPS_Lon GPS_Alt
# 0         m/s      C      uA      deg      deg      km
# 1         1.9  40.79    0.99  -1.3018  36.7593    9000
# 2         1.4  40.79    0.99  -1.3018  36.7591    9000
# 3         1.6  40.79    0.99  -1.3018  36.7591    9000
# 4         1.8  40.79    0.98  -1.3018  36.7591    9000
# ...       ...    ...     ...      ...      ...     ...
# 3681     31.1   15.3    1.66   -1.222  36.0553    9000
# 3682       31   15.3    1.65   -1.222  36.0548    9000
# 3683     30.9  15.31    1.65   -1.222  36.0542    9000
# 3684     30.8  15.31    1.65   -1.222  36.0537    9000
# 3685     30.8   15.3    1.65   -1.222  36.0531    9000
#
# [3686 rows x 15 columns]

# %%
#save df
df = (df[['Temp', 'O3_DU', 'Press']])

# %%
df
# Out:
#         Temp   O3_DU   Press
# 0          C      DU     hPa
# 1       22.3       0   826.3
# 2       22.1    0.09  824.01
# 3      21.98    0.13   822.7
# 4      21.96    0.18  821.55
# ...      ...     ...     ...
# 3681  -37.51  221.23    6.42
# 3682  -37.62  221.31    6.41
# 3683   -37.6  221.39     6.4
# 3684  -37.36  221.39     6.4
# 3685  -37.12  221.48    6.39
#
# [3686 rows x 3 columns]

# %%
#eliminating the str row
df = df[1:]

# %%
#describe the data components
df.describe
# Out:
# <bound method NDFrame.describe of         Temp   O3_DU   Press
# 1       22.3       0   826.3
# 2       22.1    0.09  824.01
# 3      21.98    0.13   822.7
# 4      21.96    0.18  821.55
# 5      21.88    0.21  820.61
# ...      ...     ...     ...
# 3681  -37.51  221.23    6.42
# 3682  -37.62  221.31    6.41
# 3683   -37.6  221.39     6.4
# 3684  -37.36  221.39     6.4
# 3685  -37.12  221.48    6.39
#
# [3685 rows x 3 columns]>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Sample data (assuming 'df' already exists)
x1 = pd.to_numeric(df["O3_DU"], errors='coerce')
x2 = pd.to_numeric(df["Temp"], errors='coerce')  
y = pd.to_numeric(df["Press"], errors='coerce')

# Create the plot
fig, ax = plt.subplots(figsize=(20, 15))

# Plot both lines
ax.plot(x1, y, label="O3_DU")
ax.plot(x2, y, label="Temp")

# Set x-axis ticks for O3_DU (optional customization)
#ax.set_xticks(np.arange(-90, 290, 20))

# Invert the y-axis (higher values at the top)
ax.invert_yaxis()

# Add labels and title
#ax.set_xlabel("DU Value")
ax.set_ylabel("Pressure")
ax.set_title("O3_DU and Temp U vs Pressure")

# Add legend
ax.legend()

# Show the plot
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Sample data (assuming 'df' already exists)
x = pd.to_numeric(df["O3_DU"], errors='coerce')
y = pd.to_numeric(df["Press"], errors='coerce')

# Create the plot
fig, ax = plt.subplots(figsize=(30, 15))
ax.plot(x, y)

# Set x-axis ticks
#ax.set_xticks(np.arange(-90, 300, 20))

# Invert the y-axis
ax.set_ylim(max(y), min(y))

# Add labels and title
ax.set_xlabel("O3_DU")
ax.set_ylabel("Pressure")
ax.set_title("Ozone Profile")

# Show the plot
plt.show()

# %%
# Sample data
x =  pd.to_numeric(df["Temp"])
y =  pd.to_numeric(df["Press"])

# Create the plot
fig, ax = plt.subplots()
ax.plot(x, y)


# Invert the y-axis
#fig.set_ylim(max(y), 0) # Set the highest y value at the bottom

# Invert the y-axis (higher values at the top)
ax.invert_yaxis()

# Add labels and title
ax.set_xlabel("X-axis")
ax.set_ylabel("Y-axis")
ax.set_title("Temp Profile")

# Show the plot
plt.show()

# %%
import pandas as pd

df = pd.read_csv("OZONE_DATA.csv")

df
# Out:
#       Time   Press GeopAlt    Temp  RH  O3_mPa O3_ppmv   O3_DU Wind_Dir  \
# 0      sec     hPa      km       C   %     mPa    ppmv      DU      deg
# 1        0   826.3     1.8    22.3  62  3.8806   0.047       0       42
# 2        2  824.01   1.824    22.1  53  3.8806  0.0471    0.09       89
# 3        4   822.7   1.838   21.98  53  3.8806  0.0472    0.13       91
# 4        6  821.55    1.85   21.96  54  3.8398  0.0467    0.18       88
# ...    ...     ...     ...     ...  ..     ...     ...     ...      ...
# 3681  7360    6.42  34.039  -37.51   1  6.6706    10.4  221.23       91
# 3682  7362    6.41   34.05  -37.62   1  6.6303    10.3  221.31       91
# 3683  7364     6.4  34.061   -37.6   1  6.6312    10.4  221.39       91
# 3684  7366     6.4  34.061  -37.36   1  6.6312    10.4  221.39       91
# 3685  7368    6.39  34.071  -37.12   1  6.6318    10.4  221.48       91
#
#      Wind_Spd  TPump O3CellI  GPS_Lat  GPS_Lon GPS_Alt
# 0         m/s      C      uA      deg      deg      km
# 1         1.9  40.79    0.99  -1.3018  36.7593    9000
# 2         1.4  40.79    0.99  -1.3018  36.7591    9000
# 3         1.6  40.79    0.99  -1.3018  36.7591    9000
# 4         1.8  40.79    0.98  -1.3018  36.7591    9000
# ...       ...    ...     ...      ...      ...     ...
# 3681     31.1   15.3    1.66   -1.222  36.0553    9000
# 3682       31   15.3    1.65   -1.222  36.0548    9000
# 3683     30.9  15.31    1.65   -1.222  36.0542    9000
# 3684     30.8  15.31    1.65   -1.222  36.0537    9000
# 3685     30.8   15.3    1.65   -1.222  36.0531    9000
#
# [3686 rows x 15 columns]

# %%
df[['GeopAlt', 'O3_mPa', 'Temp']]
# Out:
#      GeopAlt  O3_mPa    Temp
# 0         km     mPa       C
# 1        1.8  3.8806    22.3
# 2      1.824  3.8806    22.1
# 3      1.838  3.8806   21.98
# 4       1.85  3.8398   21.96
# ...      ...     ...     ...
# 3681  34.039  6.6706  -37.51
# 3682   34.05  6.6303  -37.62
# 3683  34.061  6.6312   -37.6
# 3684  34.061  6.6312  -37.36
# 3685  34.071  6.6318  -37.12
#
# [3686 rows x 3 columns]

# %%
df=(df[['GeopAlt', 'O3_mPa', 'Temp']])
df
# Out:
#      GeopAlt  O3_mPa    Temp
# 0         km     mPa       C
# 1        1.8  3.8806    22.3
# 2      1.824  3.8806    22.1
# 3      1.838  3.8806   21.98
# 4       1.85  3.8398   21.96
# ...      ...     ...     ...
# 3681  34.039  6.6706  -37.51
# 3682   34.05  6.6303  -37.62
# 3683  34.061  6.6312   -37.6
# 3684  34.061  6.6312  -37.36
# 3685  34.071  6.6318  -37.12
#
# [3686 rows x 3 columns]

# %%
df = df[1:]
df
# Out:
#      GeopAlt  O3_mPa    Temp
# 1        1.8  3.8806    22.3
# 2      1.824  3.8806    22.1
# 3      1.838  3.8806   21.98
# 4       1.85  3.8398   21.96
# 5       1.86  3.8398   21.88
# ...      ...     ...     ...
# 3681  34.039  6.6706  -37.51
# 3682   34.05  6.6303  -37.62
# 3683  34.061  6.6312   -37.6
# 3684  34.061  6.6312  -37.36
# 3685  34.071  6.6318  -37.12
#
# [3685 rows x 3 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df=(df[["O3_mPa", 'Temp', 'GeopAlt']])

# Sample data (assuming 'df' already exists)
x1 = pd.to_numeric(df["O3_mPa"], errors='coerce')
x2 = pd.to_numeric(df["Temp"], errors='coerce')  
y = pd.to_numeric(df["GeopAlt"], errors='coerce')

# %%
df = pd.DataFrame(df)
print(df)
# Out:
#       O3_mPa    Temp GeopAlt
# 1     3.8806    22.3     1.8
# 2     3.8806    22.1   1.824
# 3     3.8806   21.98   1.838
# 4     3.8398   21.96    1.85
# 5     3.8398   21.88    1.86
# ...      ...     ...     ...
# 3681  6.6706  -37.51  34.039
# 3682  6.6303  -37.62   34.05
# 3683  6.6312   -37.6  34.061
# 3684  6.6312  -37.36  34.061
# 3685  6.6318  -37.12  34.071
#
# [3685 rows x 3 columns]

# %%
df
# Out:
#       O3_mPa    Temp GeopAlt
# 1     3.8806    22.3     1.8
# 2     3.8806    22.1   1.824
# 3     3.8806   21.98   1.838
# 4     3.8398   21.96    1.85
# 5     3.8398   21.88    1.86
# ...      ...     ...     ...
# 3681  6.6706  -37.51  34.039
# 3682  6.6303  -37.62   34.05
# 3683  6.6312   -37.6  34.061
# 3684  6.6312  -37.36  34.061
# 3685  6.6318  -37.12  34.071
#
# [3685 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Ensure numeric values and clean data
df['Temp'] = pd.to_numeric(df['Temp'], errors='coerce')
df['O3_mPa'] = pd.to_numeric(df['O3_mPa'], errors='coerce')
df['GeopAlt'] = pd.to_numeric(df['GeopAlt'], errors='coerce')
df = df.dropna(subset=['Temp', 'O3_mPa', 'GeopAlt'])

# Optional: remove extreme O3 outliers if needed (e.g., > 15 mPa)
df = df[df['O3_mPa'] < 15]

# Sort by altitude
df = df.sort_values('GeopAlt')

# Create the plot
plt.figure(figsize=(10, 8))

# Plot both temperature and ozone on same x-axis
plt.plot(df['Temp'], df['GeopAlt'], color='red', linestyle='--', label='Temperature (°C)')
plt.plot(df['O3_mPa'], df['GeopAlt'], color='blue', linestyle='-', label='O₃ (mPa)')

# Axis labels and title
plt.xlabel('(°C or mPa)')
plt.ylabel('Geopotential Altitude (km)')
plt.title('Temperature and Ozone Vertical Profile')

# Grid, legend, and layout
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Ensure numeric values and clean data
df['O3_mPa'] = pd.to_numeric(df['O3_mPa'], errors='coerce')
df['GeopAlt'] = pd.to_numeric(df['GeopAlt'], errors='coerce')
df = df.dropna(subset=['O3_mPa', 'GeopAlt'])

# Optional: remove extreme O3 outliers if needed (e.g., > 15 mPa)
df = df[df['O3_mPa'] < 15]

# Sort by altitude
df = df.sort_values('GeopAlt')

# Create the plot
plt.figure(figsize=(10, 8))

# Plot ozone against GeoptAlt
plt.plot(df['O3_mPa'], df['GeopAlt'], color='blue', linestyle='-', label='O₃ (mPa)')

# Axis labels and title
plt.xlabel('°mPa')
plt.ylabel('Geopotential Altitude (km)')
plt.title('Ozone Vertical Profile')

# Grid, legend, and layout
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Ensure numeric values and clean data
df['Temp'] = pd.to_numeric(df['Temp'], errors='coerce')
df['GeopAlt'] = pd.to_numeric(df['GeopAlt'], errors='coerce')
df = df.dropna(subset=['Temp', 'GeopAlt'])


# Sort by altitude
df = df.sort_values('GeopAlt')

# Create the plot
plt.figure(figsize=(10, 8))

# Plot temperature against GeoptAlt
plt.plot(df['Temp'], df['GeopAlt'], color='red', linestyle='--', label='Temperature (°C)')

# Axis labels and title
plt.xlabel('°C')
plt.ylabel('Geopotential Altitude (km)')
plt.title('Temperature Vertical Profile')

# Grid, legend, and layout
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
